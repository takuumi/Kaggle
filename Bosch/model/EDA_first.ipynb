# %% [markdown]
# # numを5000行見てみる。

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier as RandomForest

import random

from sklearn import linear_model

pd.set_option("display.max_columns", 5000)

df_numeric = pd.read_csv("train_numeric.csv", encoding='utf-8', nrows=10000)

df_numeric.head(5000)
# Out:
#         Id  L0_S0_F0  L0_S0_F2  L0_S0_F4  L0_S0_F6  L0_S0_F8  L0_S0_F10  \
# 0        4     0.030    -0.034    -0.197    -0.179     0.118      0.116
# 1        6       NaN       NaN       NaN       NaN       NaN        NaN
# 2        7     0.088     0.086     0.003    -0.052     0.161      0.025
# 3        9    -0.036    -0.064     0.294     0.330     0.074      0.161
# 4       11    -0.055    -0.086     0.294     0.330     0.118      0.025
# 5       13     0.003     0.019     0.294     0.312     0.031      0.161
# 6       14       NaN       NaN       NaN       NaN       NaN        NaN
# 7       16       NaN       NaN       NaN       NaN       NaN        NaN
# 8       18    -0.016    -0.041    -0.179    -0.179    -0.056      0.161
# 9       23       NaN       NaN       NaN       NaN       NaN        NaN
# 10      26     0.016     0.093    -0.015    -0.016     0.031      0.116
# 11      27    -0.062    -0.153    -0.197    -0.179    -0.187     -0.384
# ...

# %%
### Nanが結構あるなー
# とりあえず図示

# %%
import seaborn as sns
plt.figure(figsize=(16, 8)) 
sns.heatmap(df_numeric.fillna(0).drop(columns='Id'))

# %%
# S29あたりなんかいろいろありそう。

# %%
# 詳細に
print(df_numeric['L3_S29_F3476'].fillna(0).min(), df_numeric['L3_S29_F3476'].fillna(0).max())

plt.plot(df_numeric['L3_S29_F3476'].fillna(0)[400:600], color = 'blue', alpha = 0.5)
# Out:
# -0.107 0.152

# %% [markdown]
# ### ↑みたいな変な値がOK・NGに寄与しているか、見ればよいのか。TODO:ok - ng 比較

# %%
# お隣さんは？
plt.plot(df_numeric['L3_S29_F3473'].fillna(0), color = 'green', alpha = 0.3)
plt.plot(df_numeric['L3_S29_F3476'].fillna(0), color = 'blue', alpha = 0.3)
plt.plot(df_numeric['L3_S29_F3479'].fillna(0), color = 'red', alpha = 0.3)

# %%
# 異常値ID その時の結果は？
l3_anomary_index = df_numeric[df_numeric['L3_S29_F3476'] == max(df_numeric['L3_S29_F3476'])].index
df_tmp = df_numeric['Response']
print(df_tmp.loc[df_tmp.values == True].tail(20))

print("L3Anomary : {}".format(l3_anomary_index))
# Out:
# 5454    1
# 5720    1
# 5815    1
# 5879    1
# 5961    1
# 6004    1
# 6178    1
# 6229    1
# 6255    1
# 6316    1
# 6442    1
# 6661    1
# 6965    1
# 6974    1
# 8105    1
# 8265    1
# 8411    1
# 8950    1
# 9112    1
# 9421    1
# Name: Response, dtype: int64
# L3Anomary : Int64Index([8280], dtype='int64')

# %%
print (df_numeric.columns.get_loc('L3_S29_F3330'))
print (df_numeric.columns.get_loc('L3_S29_F3476'))
df_s29 = df_numeric.loc[:, 'L3_S29_F3330':'L3_S29_F3476']

plt.figure(figsize=(16, 8)) 
sns.heatmap(df_s29)
# Out:
# 729
# 771

# %% [markdown]
# df_response = df_numeric.Response
#
# df_s29_999 = df_s29.fillna(999)
# rf = RandomForest(n_estimators=100)
# rf_model = rf.fit(df_s29_999, df_response)
# rf_model.score(df_s29_999, df_response)
#
# #df_s29.columns[np.argsort(rf_model.feature_importances_)].tolist()
#
# #特徴量重要度を表示
# for i in range(0, df_s29_999.shape[1]):
#     if 0 < rf_model.feature_importances_[i]:
#         print("{}:{}".format(df_s29_999.columns[i], rf_model.feature_importances_[i]))
#
#
# #clf.fit(df_x, df_y)

# %%
# 以下は知らない実装メモ

# %%
df_y_pre = pd.DataFrame(np.zeros(len(df_none_usecols)), columns=['Response']).astype('bool')


print (df_y_pre.head())
print (df_none_usecols.head())

#for i in range(len(df_none_usecols)):
#    if (i % 250 == 0):
#        df_y_pre[i] = 1
FaultsNum = len(df_none_usecols)//250
Len = len(df_none_usecols)
for i in range(FaultsNum):
    num = random.randint(1,Len-1)
    df_y_pre.iloc[num, :] = True
# Out:
#    Response
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#    Id
# 0   1
# 1   2
# 2   3
# 3   5
# 4   8

# %%
pd_kaitou = df_none_usecols.join([df_y_pre])
pd_kaitou.to_csv('kaitou.csv', index=False)

# %%
df_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Columns: 970 entries, Id to Response
# dtypes: float64(968), int64(2)
# memory usage: 74.0 MB

# %%
from collections import Counter

Counter(df_numeric.fillna(19999).L0_S0_F0)
# Out:
# Counter({0.03: 173,
#          19999.0: 4267,
#          0.08800000000000001: 102,
#          -0.036000000000000004: 150,
#          -0.055: 135,
#          0.003: 159,
#          -0.016: 189,
#          0.016: 223,
#          -0.062: 132,
#          -0.075: 117,
#          -0.003: 194,
#          0.252: 2,
#          0.01: 181,
#          0.036000000000000004: 178,
#          0.062: 139,
#          -0.16699999999999998: 35,
#          0.10099999999999999: 85,
#          0.10800000000000001: 64,
#          -0.028999999999999998: 184,
#          0.095: 89,
#          0.075: 143,
#          -0.251: 4,
#          0.049: 172,
#          -0.023: 194,
#          0.023: 183,
#          0.141: 45,
#          -0.049: 129,
#          -0.042: 167,
#          0.069: 160,
#          -0.10800000000000001: 59,
#          0.128: 49,
#          -0.095: 117,
#          0.154: 30,
#          0.121: 65,
#          -0.114: 64,
#          -0.01: 189,
#          0.055999999999999994: 147,
# ...

# %%
a=df_numeric.fillna(9999).L0_S0_F0.astype('bool')
a.loc[a==False]
# Out:
# Series([], Name: L0_S0_F0, dtype: bool)
